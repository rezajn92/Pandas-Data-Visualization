# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as py
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Creating the scatter plot **

# %%
df3.plot.scatter(x='a', y='b',s=50, figsize=(12,3), c='red' )
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ** Creating a histogram of the 'a' column.**

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=30, alpha=0.4, color='red')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ** Creating a boxplot comparing the a and b columns.**

# %%
plt.style.use('ggplot')

# %%
df3[['a','b']].boxplot(color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ** Creating a kde plot of the 'd' column **

# %%
plt.style.use('ggplot')

# %%
df3['d'].plot.kde(color='red')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.style.use('ggplot')

# %%
df3['d'].plot.kde(color='red', style='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Creating an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.loc[0:30].plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ** Displayingg the legend outside of the plot **

# %%
df3.loc[0:30].plot.area()
plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
